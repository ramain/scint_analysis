# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import scipy.optimize as so
import faraday_tools as ft

# %%
def StokesPars(Pulse):
    I = Pulse[...,(0,3)].sum(-1) / 2
    Q = ( Pulse[...,0] - Pulse[...,3] ) / 2
    U = Pulse[...,1]
    V = Pulse[...,2]
    return I, Q, U, V

# %%
def MockData(pars, resp):
    '''
    Generates mock stokes parameters, as observed at ARO
    
    pars: len 6 array containing q, u, v, lag, RM, phi
    resp: Frequency response of the observation
    q, u, v: Relative fraction of Q, U, V
    lag: Time delay of cables
    RM: Rotation measure
    Phi: Phase - calibrates the rotation measure
    '''
    q, u, v, lag, RM, phi = pars[0], pars[1], pars[2], pars[3], pars[4], pars[5]
    
    IC = np.array([q,u,v])  # Q, U, V
    IC = IC / np.linalg.norm(IC)  # Normalize, so I^2 = Q^2 + U^2 + V^2

    # Define Frequency and wavelength
    freq = np.linspace(400,800,1024)
    lam = (300. / freq)
    
    # Generate flat spectra of Q, U, V, multiply by the response
    Q0 = IC[0] * resp * np.ones_like(freq)
    U0 = IC[1] * resp * np.ones_like(freq)
    V0 = IC[2] * resp * np.ones_like(freq)

    # Rotation vectors of faraday rotation and cable delay
    vecFR = np.exp(2j * (RM*lam**2.0 + phi))
    vecCD = np.exp(2j*np.pi*(np.arange(1024)/1024. * lag)) 

    # Rotate P in ISM, before reaching telescope
    P0 = Q0 + 1j*U0
    P0 *= vecFR

    # Cable delays mix measured U (U rotated between Q) and true V
    XY0 = np.imag(P0) + 1j*V0
    XY0 *= vecCD

    # Final values, as measured by the telescope
    Q = np.real(P0)
    U = np.real(XY0)
    V = np.imag(XY0)
    
    return Q, U, V

# %%
def DiffData(pars, data, resp):
    '''
    Generates mock stokes parameters, as observed at ARO
    
    resp: Frequency response of the observation
    q, u, v: Relative fraction of Q, U, V
    lag: Time delay of cables
    RM: Rotation measure
    Phi: Phase - calibrates the rotation measure
    '''
    q, u, v, lag, RM, phi = pars[0], pars[1], pars[2], pars[3], pars[4], pars[5]
    
    IC = np.array([q,u,v])  # Q, U, V

    # Define Frequency and wavelength
    freq = np.linspace(400,800,1024)
    lam = (300. / freq)
    
    # Generate flat spectra of Q, U, V, multiply by the response
    Q0 = IC[0] * resp * np.ones_like(freq)
    U0 = IC[1] * resp * np.ones_like(freq)
    V0 = IC[2] * resp * np.ones_like(freq)

    # Rotation vectors of faraday rotation and cable delay
    vecFR = np.exp(2j * (RM*lam**2.0 + phi))
    vecCD = np.exp(2j*np.pi*(np.arange(1024)/1024. * lag)) 

    # Rotate P in ISM, before reaching telescope
    P0 = Q0 + 1j*U0
    P0 *= vecFR

    # Cable delays mix measured U (U rotated between Q) and true V
    XY0 = np.imag(P0) + 1j*V0
    XY0 *= vecCD

    # Final values, as measured by the telescope
    Q = np.real(P0)
    U = np.real(XY0)
    V = np.imag(XY0)
    
    #data_Q = data 
    data_Q, data_U, data_V = data[0], data[1], data[2]
    
    return (Q-data_Q)**2.0 + (U-data_U)**2.0 + (V-data_V)**2.0
    #return (V-data_V)**2.0

# %%
def LSQ(data, model):
    lsq = (data - model)**2.0
    return lsq.sum()

# %%
'''
Get Stokes I from real data, as initial condition for simulation
'''

#n = np.load('data/Crab_Foldedspec.npy')
n = np.load('data/B1937_Foldedspec.npy')

#Catalogue value of RM for initial guess
RM = 6.7
plt.imshow(n[:,:,(0,3)].sum(-1),aspect='auto',extent=[0,2*np.pi,400,800], interpolation='nearest',cmap=cm.inferno )
plt.xlabel('phase [rad]')
plt.ylabel('Frequency [MHz]')

# %%
#MPspec = n[:,-5:-1,:].sum(1) # Crab Main Pulse
MPspec = n[:,60:75,:].sum(1) # B1937 Main Pulse

I, Q, U, V = StokesPars(MPspec)
freq = np.linspace(400,800,1024)
lam = (300. / freq)

# %%
plt.plot(freq, I, label='I')
plt.plot(freq, Q, label='Q')
plt.plot(freq, U, label='U')
plt.plot(freq, V, label='V')

plt.legend()
plt.xlabel('Frequency [MHz]')
plt.ylabel('Stokes Pars')

# %%
'''
Sanity Check, see that I^2 = Q^2 + U^2 + V^2
'''

plt.plot(freq, I**2.0)
plt.plot(freq, Q**2.0 + U**2.0 + V**2.0)
plt.xlabel('Frequency [MHz]')
plt.ylabel('Intensity')

# %%
# Look at the phases of P and XY
P = Q + 1j*U
XY = U + 1j*V

XYphi = np.angle(XY)
Pphi = np.angle(P)

plt.subplot(211)
plt.plot(freq, np.angle(XY), 'bx')
plt.xlabel('frequency [MHz]')
plt.ylabel('Z phi')

plt.subplot(212)
plt.plot(lam**2.0, np.angle(P), 'rx')
plt.xlabel('wavelength^2')
plt.ylabel('P phi')

# %%
binf = 8
#Ibin = I.reshape(len(I)/binf,binf).mean(-1)  # Response of total intensity
Ibin = np.sqrt(Q**2.0+U**2.0+V**2.0).reshape(len(I)/binf,binf).mean(-1)  # Response of Q^2 + U^2 + V^2
Ical = np.repeat(Ibin, binf)
plt.subplot(211)
plt.plot(I)
plt.plot(Ical,'r')

plt.subplot(212)
plt.plot((Q**2.0 + U**2.0 + V**2.0) / Ical**2.0)

# %%
"""
Fit for cable delay in V, apply to U, V

First, find a good guess for the Cable delay from the FFT
"""

XYnorm = (U + 1j*V) / Ical
FT = np.fft.rfft(np.imag(XYnorm))
FTfreq = np.fft.rfftfreq(len(V))
plt.plot(abs(FT)[:20])
plt.xlabel('Delay spacing [bins]')

lag = np.argmax(abs(FT))
print("Peak delay:", lag)
# Out:
# ('Peak delay:', 5)

# %%
p0 = np.array([1, 0, 0, lag, RM, -2])
data = np.array([Q,U,V])

b_fit = so.leastsq(DiffData, p0, args=(data, Ical), maxfev=10000)[0]
print(b_fit)

q, u, v = MockData(b_fit, Ical)

'''
#First HardCoded attempt
bins = 20
lag_range = np.linspace(lag-1,lag+1,bins)
RM_range = np.linspace(RM-1, RM+1, bins)
phi_range = np.linspace(-np.pi, np.pi, bins)
best = 1e10

for a in lag_range:
    for b in RM_range:
        for c in phi_range:
            vec = np.array([2, 1, 0, a, b, c])
            q, u, v = MockData(vec, Ical)
            lsq = LSQ(Q, q) + LSQ(U, u) + LSQ(V, v)
            if lsq < best:
                best = lsq
                q_fit, u_fit, v_fit = q, u, v
                lag_fit, RM_fit, phi_fit = a, b, c
'''

plt.subplot(311)
plt.plot(freq, Q)
plt.plot(freq, q)
plt.ylabel('Q')

plt.subplot(312)
plt.plot(freq, U) 
plt.plot(freq, u)
plt.ylabel('U')

plt.subplot(313)
plt.plot(freq, V)
plt.plot(freq, v)
plt.ylabel('V')
plt.xlabel('Frequency [MHz]')
# Out:
# [ 0.48096949  0.6969412   0.11240315  5.25933662  7.09998717 -4.1575137 ]

# %%
'''
Apply first cable delay solution to XY = U + iV,
then Faraday rotation to P = Q + iU
'''

vecCD = np.exp(-2j*np.pi*(np.arange(1024)/1024. * b_fit[3]))
vecFR = np.exp(-2j * (b_fit[4]*lam**2.0 + b_fit[5]))
         
XYcorr = XYnorm*vecCD*Ical
U_CD = np.real(XYcorr)
V_final = np.imag(XYcorr)

Pnorm = (Q + 1j*U_CD) / Ical
Pcorr = Pnorm * vecFR * Ical

V_final = np.imag(XYcorr)
Q_final = np.real(Pcorr)
U_final = np.imag(Pcorr)

plt.plot(Q_final)
plt.plot(U_final)
plt.plot(V_final)

# %%
plt.subplot(211)
plt.plot(lam**2.0, np.angle(Pcorr), 'bx', label='After removing FR and CD')
plt.plot(lam**2.0, np.angle(P), 'r+', label='Initial P')

plt.ylabel('P angle')
plt.xlabel('lambda^2')

plt.subplot(212)
plt.plot(freq, np.angle(XYcorr), 'bx', label='After removing FR and CD')
plt.plot(freq, np.angle(XY), 'r+', label='Initial XY')


plt.ylabel('XY angle')
plt.xlabel('frequency')

# %%
"""
Update Q and U, should now have finished product
"""

Q_CD_FR = np.real(Pcorr)
U_CD_FR = np.imag(Pcorr)

Pfrac = abs(Pcorr*Ical).sum() / I.sum()
Pangle = np.angle(Pcorr.sum())

print("|P| / I = ", Pfrac)
print("Pol angle = ", Pangle)

plt.plot(freq,I)
plt.plot(freq,abs(Pcorr))
plt.plot(freq,V_final)
# Out:
# ('|P| / I = ', 9.6270367173408591)
# ('Pol angle = ', 0.91198141824776757)

# %%
"""
Compare folded spectrum
"""

#n2=np.roll(n, 20, axis=1)
n2=n

nI, nQ, nU, nV = StokesPars(n2)

nXY = nU + 1j*nV
nXY_CD = nXY* vecCD[:,np.newaxis]
nU_CD = np.real(nXY_CD)
nV_final = np.imag(nXY_CD)

nP = nQ + 1j*nU_CD
nPderot = nP * vecFR[:,np.newaxis]

nQ_final = np.real(nPderot)
nU_final = np.imag(nPderot)

plt.plot(nI.sum(0), label='I')
plt.plot(abs(nPderot).sum(0), label='|P|' )
plt.plot(nV_final.sum(0), label='|V|' )

plt.legend()
plt.xlabel('phase')
plt.ylabel('intensity')

# %%
"""
Look at polarization angle
"""

plt.subplot(221)
plt.plot(180/np.pi * np.angle(nPderot.sum(0))[50:100], 'bx')
plt.ylabel('Pol angle [degrees]')

plt.subplot(222)
plt.plot(180/np.pi * np.angle(nPderot.sum(0))[180:230], 'rx')

plt.subplot(223)
plt.plot(nI.sum(0)[50:100])
plt.ylabel('Intensity')
plt.xlabel('Main Pulse')

plt.subplot(224)
plt.plot(nI.sum(0)[180:230],'r')
plt.xlabel('Interpulse')
